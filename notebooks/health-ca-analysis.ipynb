# %%
rm(list = ls())

# %%
library(ca)

# %%
(health <- data.frame(row.names = c("16-24", "25-34", "35-44", "45-54", "55-64", "65-74", "75+"), 
                    "Muy Buena" = c(19.9,17.8, 14.2, 10.5, 5.8, 6.2, 5.1),
                    "Buena" = c(64.5, 65.6, 63.6, 54.5, 45.5, 37.4, 34.3),
                    "Regular" = c(13.7, 13.3, 17.5, 27.4, 33.7, 39.8, 39.6),
                    "Mala" = c(1.5, 2.8, 4.0, 5.8, 11.7, 13.7, 16.7),
                    "Muy Mala" = c(0.5, 0.5, 0.8, 1.9, 3.3, 2.8, 4.3)))
# Out:
#       Muy.Buena Buena Regular Mala Muy.Mala
# 16-24 19.9      64.5  13.7     1.5 0.5
# 25-34 17.8      65.6  13.3     2.8 0.5
# 35-44 14.2      63.6  17.5     4.0 0.8
# 45-54 10.5      54.5  27.4     5.8 1.9
# 55-64  5.8      45.5  33.7    11.7 3.3
# 65-74  6.2      37.4  39.8    13.7 2.8
# 75+    5.1      34.3  39.6    16.7 4.3

# %%
(health.ca <- ca(health))
# Out:
#  Principal inertias (eigenvalues):
#            1       2        3        4
# Value      0.14388 0.002467 0.001326 0.000399
# Percentage 97.17%  1.67%    0.9%     0.27%
#
#
#  Rows:
#             16-24     25-34     35-44     45-54     55-64    65-74      75+
# Mass     0.142959  0.142816  0.142959  0.142959  0.142816 0.142674 0.142816
# ChiDist  0.467592  0.426207  0.299261  0.090849  0.284282 0.420192 0.530258
# Inertia  0.031257  0.025943  0.012803  0.001180  0.011542 0.025191 0.040156
# Dim. 1  -1.219917 -1.119048 -0.776758 -0.091212  0.731767 1.093619 1.384729
# Dim. 2   1.139068  0.559557 -0.739513 -1.492680 -0.967735 0.228350 1.274274
#
#
#  Columns:
#         Muy.Buena     Buena   Regular     Mala Muy.Mala
# Mass     0.113539  0.521851  0.264210 0.080263 0.020137
# ChiDist  0.493159  0.234225  0.410070 0.685975 0.691580
# Inertia  0.027613  0.028630  0.044429 0.037769 0.009631
# Dim. 1  -1.263325 -0.611637  1.073531 1.785854 1.770101
# ...

# %%
plot(health.ca)
# Out:
# plot without title
