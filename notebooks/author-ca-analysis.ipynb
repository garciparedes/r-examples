# %%
rm(list = ls())

# %%
library(ca)

# %%
data(author)
(author.use <- author / sum(author))
# Out:
#                              a           b            c           d
# three daughters (buck)       0.006575251 0.0013867802 0.001757385 0.004471171
# drifters (michener)          0.006156826 0.0013030951 0.002056260 0.003718005
# lost world (clark)           0.007053451 0.0013389602 0.002163855 0.003168075
# east wind (buck)             0.006658936 0.0015421952 0.001530240 0.004100565
# farewell to arms (hemingway) 0.007041496 0.0008607601 0.001542195 0.004052745
# sound and fury 7 (faulkner)  0.006467656 0.0013030951 0.001625880 0.002725740
# sound and fury 6 (faulkner)  0.006180736 0.0011476801 0.001518285 0.004255980
# profiles of future (clark)   0.007077361 0.0018052052 0.003000705 0.002845290
# islands (hemingway)          0.006886081 0.0014346002 0.001625880 0.004829821
# pendorric 3 (holt)           0.006658936 0.0011596351 0.001733475 0.004232070
# asia (michener)              0.006623071 0.0012911401 0.002462730 0.002905065
# ...

# %%
author.use.ca <- ca(author.use)

author.use.ca$rowmass %*% t(author.use.ca$colmass) *
    (1 + author.use.ca$rowcoord %*%
     diag(author.use.ca$sv) %*%
     t(author.use.ca$colcoord))
# Out:
#                              a           b            c           d
# three daughters (buck)       0.006575251 0.0013867802 0.001757385 0.004471171
# drifters (michener)          0.006156826 0.0013030951 0.002056260 0.003718005
# lost world (clark)           0.007053451 0.0013389602 0.002163855 0.003168075
# east wind (buck)             0.006658936 0.0015421952 0.001530240 0.004100565
# farewell to arms (hemingway) 0.007041496 0.0008607601 0.001542195 0.004052745
# sound and fury 7 (faulkner)  0.006467656 0.0013030951 0.001625880 0.002725740
# sound and fury 6 (faulkner)  0.006180736 0.0011476801 0.001518285 0.004255980
# profiles of future (clark)   0.007077361 0.0018052052 0.003000705 0.002845290
# islands (hemingway)          0.006886081 0.0014346002 0.001625880 0.004829821
# pendorric 3 (holt)           0.006658936 0.0011596351 0.001733475 0.004232070
# asia (michener)              0.006623071 0.0012911401 0.002462730 0.002905065
# ...
